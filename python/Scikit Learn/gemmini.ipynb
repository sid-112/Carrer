# %%
from google import genai

client = genai.Client(api_key="AIzaSyAM3OV7jj15MxS7uUi6TP2O3qjHXQ0kolI")
response = client.models.generate_content(
    model="gemini-2.0-flash", contents="Explain how AI works"
)
print(response.text)
# Out:
# Okay, let's break down how AI (Artificial Intelligence) works.  It's a broad field, so I'll cover the core concepts and common techniques:
#
# **What is AI?**
#
# At its most basic, AI is about creating machines that can perform tasks that typically require human intelligence. These tasks can include:
#
# *   **Learning:**  Acquiring information and rules for using it.
# *   **Reasoning:** Applying rules to reach conclusions.
# *   **Problem-solving:**  Finding solutions to complex issues.
# *   **Perception:** Understanding sensory input (like images, sound, or text).
# *   **Natural Language Processing (NLP):**  Understanding and generating human language.
#
# **Core Concepts and Techniques**
#
# The way AI accomplishes these tasks varies widely, but here are some of the fundamental approaches:
#
# 1.  **Machine Learning (ML):**
#
# ...
