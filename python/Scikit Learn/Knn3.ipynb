# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('C:\Edu\coding\python\Scikit Learn\Cgpa2.csv')
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\E'
# <>:1: SyntaxWarning: invalid escape sequence '\E'
# C:\Users\User\AppData\Local\Temp\ipykernel_6704\3834679367.py:1: SyntaxWarning: invalid escape sequence '\E'
#   df = pd.read_csv('C:\Edu\coding\python\Scikit Learn\Cgpa2.csv')
#    CGPA  IQ
# 0   5.5  34
# 1   4.2  67
# 2   5.6  23
# 3   9.1  89
# 4   4.8  56
# 5   2.2  94
# 6   6.2  82
# 7   5.7  72
# 8   9.4  87
# 9   5.7  12

# %%
df.head()
# Out:
#    CGPA  IQ
# 0   5.5  34
# 1   4.2  67
# 2   5.6  23
# 3   9.1  89
# 4   4.8  56

# %%
df.shape
# Out:
# (10, 2)

# %%
df.describe()
# Out:
#             CGPA         IQ
# count  10.000000  10.000000
# mean    5.840000  61.600000
# std     2.125611  29.330303
# min     2.200000  12.000000
# 25%     4.975000  39.500000
# 50%     5.650000  69.500000
# 75%     6.075000  85.750000
# max     9.400000  94.000000

# %%
X = df.CGPA
y = df.IQ

plt.scatter(X, y)

# %%
X_train, y_train, X_test, y_test  = train_test_split(X, y, random_state=13, test_size=0.2)

model = LinearRegression()
 
X_test = X[:-5].values.reshape(-1, 1)
X_train = X[-5:].values.reshape(-1, 1)
y_test = y[:-5]
y_train = y[-5:]

model.fit(X_train, y_train)
y_prede = model.predict(X_test)

plt.scatter(X_test, y_test)
plt.plot(X_test, y_prede)

# %%
print(model.coef_, model.intercept_)
# Out:
# [-0.56262456] 72.68572742603098

# %%
sc = StandardScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train
# Out:
# array([[-1.59342894],
#        [ 0.15759187],
#        [-0.06128573],
#        [ 1.55840852],
#        [-0.06128573]])

# %%
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
y_pred = knn.predict(X_test)

accuracy_score(y_test, y_pred)
# Out:
# 0.0
